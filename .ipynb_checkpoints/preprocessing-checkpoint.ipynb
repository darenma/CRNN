# %%
import numpy as np
import pandas as pd

# %%
! ls
# Out:
# 55175_105481_compressed_yoochoose-buys.dat.zip
# 55175_105481_compressed_yoochoose-clicks.dat.zip
# 55175_105481_compressed_yoochoose-test.dat.zip
# preprocessing.ipynb
# yoochoose-buys.dat
# yoochoose-clicks.dat
# yoochoose-test.dat

# %%
path_buys = "yoochoose-buys.dat"
path_clicks = "yoochoose-clicks.dat"
path_test = "yoochoose-test.dat"

# %%
buys_head = ["session_id","time", "item_id", "price", "quantity"]
clicks_head = ["session_id","time", "item_id", "category"]
test_head = ["session_id","time", "item_id", "category"]

# %%
buys = pd.read_csv(path_buys, sep=',', names=buys_head)
clicks = pd.read_csv(path_clicks, sep=',', names=clicks_head)
test = pd.read_csv(path_test, sep=',', names=test_head)
# Out:
# /Users/darenma/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
buys.head()
# Out:
#    session_id                      time    item_id  price  quantity
# 0      420374  2014-04-06T18:44:58.314Z  214537888  12462         1
# 1      420374  2014-04-06T18:44:58.325Z  214537850  10471         1
# 2      281626  2014-04-06T09:40:13.032Z  214535653   1883         1
# 3      420368  2014-04-04T06:13:28.848Z  214530572   6073         1
# 4      420368  2014-04-04T06:13:28.858Z  214835025   2617         1

# %%
clicks.category.unique()
# Out:
# array([0, '0', 'S', '4', '7', '3', '2', '1', '2089286907', '6', '5', '10',
#        '9', '2089422131', '11', '2089538467', '2089134472', '2088954951',
#        '2089529540', '2088904854', '12', '2088962571', '2089074648',
#        '2088937105', '2088942073', '2089437536', '2089045199',
#        '2089538518', '2089318666', '2089046251', '2089080971',
#        '2089318689', '2089221555', '2088919107', '2089615479',
#        '2089282437', '2089286963', '2088954790', '2089322935',
#        '2088918545', '2089134726', '2089358732', '2089440550',
#        '2089282248', '2089677914', '2089580969', '2089404239',
#        '2089569829', '2089437418', '2089646261', '2089574086',
#        '2089246594', '2088894828', '2088973177', '2089142981',
#        '2089531793', '2089615685', '2088999608', '2089116929',
#        '2089546185', '2089688609', '2088901091', '2088903330',
#        '2089498194', '2089287217', '2089570176', '2089584494',
# ...

# %%
test.head()
# Out:
#    session_id                      time    item_id category
# 0           5  2014-04-07T17:13:46.713Z  214530776        0
# 1           5  2014-04-07T17:20:56.973Z  214530776        0
# 2           5  2014-04-07T17:21:19.602Z  214530776        0
# 3          10  2014-04-04T07:44:14.590Z  214820942        0
# 4          10  2014-04-04T07:45:20.245Z  214826810        0
